# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
df_pokemon = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df_pokemon
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 2          Venusaur    Grass  Poison  80      82       83      100      100
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %%
df_pokemon["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df_pokemon["Type 2"].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
df_filtered_1 = df_pokemon[["Name", "Type 1", "Type 2", "HP"]]
df_filtered_1
# Out:
#                Name   Type 1  Type 2  HP
# 0         Bulbasaur    Grass  Poison  45
# 1           Ivysaur    Grass  Poison  60
# 2          Venusaur    Grass  Poison  80
# 3     Mega Venusaur    Grass  Poison  80
# 4        Charmander     Fire     NaN  39
# ..              ...      ...     ...  ..
# 795         Diancie     Rock   Fairy  50
# 796    Mega Diancie     Rock   Fairy  50
# 797  Hoopa Confined  Psychic   Ghost  80
# 798   Hoopa Unbound  Psychic    Dark  80
# 799       Volcanion     Fire   Water  80
#
# [800 rows x 4 columns]

# %%
df_filtered_dragon_grass = df_filtered_1[(df_filtered_1["Type 1"].isin(["Dragon", "Grass"])) | (df_filtered_1["Type 2"].isin(["Dragon", "Grass"]))]
df_filtered_dragon_grass
# Out:
#                      Name  Type 1  Type 2   HP
# 0               Bulbasaur   Grass  Poison   45
# 1                 Ivysaur   Grass  Poison   60
# 2                Venusaur   Grass  Poison   80
# 3           Mega Venusaur   Grass  Poison   80
# 7        Mega Charizard X    Fire  Dragon   78
# ..                    ...     ...     ...  ...
# 786  Gourgeist Large Size   Ghost   Grass   75
# 787  Gourgeist Super Size   Ghost   Grass   85
# 790                Noibat  Flying  Dragon   40
# 791               Noivern  Flying  Dragon   85
# 794    Zygarde Half Forme  Dragon  Ground  108
#
# [144 rows x 4 columns]

# %%
df_filtered_1 = df_pokemon[["Name", "Type 1", "Type 2", "HP"]]
df_filtered_exact = df_filtered_1[
    ((df_filtered_1["Type 1"] == "Dragon") & (df_filtered_1["Type 2"] == "Grass")) |
    ((df_filtered_1["Type 1"] == "Grass") & (df_filtered_1["Type 2"] == "Dragon"))
]
df_filtered_exact
# Out:
#               Name Type 1  Type 2  HP
# 275  Mega Sceptile  Grass  Dragon  70

# %%
df_filtered_dragon = df_filtered_1[(df_filtered_1["Type 1"].isin(["Dragon"])) | (df_filtered_1["Type 2"].isin(["Dragon"]))]
df_filtered_dragon
# Out:
#                        Name    Type 1    Type 2   HP
# 7          Mega Charizard X      Fire    Dragon   78
# 159                 Dratini    Dragon       NaN   41
# 160               Dragonair    Dragon       NaN   61
# 161               Dragonite    Dragon    Flying   91
# 196           Mega Ampharos  Electric    Dragon   90
# 249                 Kingdra     Water    Dragon   75
# 275           Mega Sceptile     Grass    Dragon   70
# 360                 Vibrava    Ground    Dragon   50
# 361                  Flygon    Ground    Dragon   80
# 365                 Altaria    Dragon    Flying   75
# 366            Mega Altaria    Dragon     Fairy   75
# 406                   Bagon    Dragon       NaN   45
# 407                 Shelgon    Dragon       NaN   65
# 408               Salamence    Dragon    Flying   95
# 409          Mega Salamence    Dragon    Flying   95
# 417                  Latias    Dragon   Psychic   80
# 418             Mega Latias    Dragon   Psychic   80
# ...

# %%
df_filtered_grass = df_filtered_1[(df_filtered_1["Type 1"].isin(["Grass"])) | (df_filtered_1["Type 2"].isin(["Grass"]))]
df_filtered_grass
# Out:
#                        Name Type 1  Type 2  HP
# 0                 Bulbasaur  Grass  Poison  45
# 1                   Ivysaur  Grass  Poison  60
# 2                  Venusaur  Grass  Poison  80
# 3             Mega Venusaur  Grass  Poison  80
# 48                   Oddish  Grass  Poison  45
# ..                      ...    ...     ...  ..
# 783    Pumpkaboo Super Size  Ghost   Grass  59
# 784  Gourgeist Average Size  Ghost   Grass  65
# 785    Gourgeist Small Size  Ghost   Grass  55
# 786    Gourgeist Large Size  Ghost   Grass  75
# 787    Gourgeist Super Size  Ghost   Grass  85
#
# [95 rows x 4 columns]

# %%
mean_dragon = df_filtered_dragon["HP"].mean().round(2)
mean_grass = df_filtered_grass["HP"].mean().round(2)
print(f"The mean of Pokémon Dragon type is {mean_dragon} and Pokémon Grass type is {mean_grass}.")
# Out:
# The mean of Pokémon Dragon type is 82.9 and Pokémon Grass type is 66.05.

# %%
print(mean_dragon)
print(mean_grass)
# Out:
# 82.9
# 66.05

# %%
# Calcula con Two Sample T-test que la media de HP tipo Dragón no es menor que la de tipo Grass.
# Y así confirmamos que al no ser menor, podemos decir que es mayor.
# H0 = Dragon HP <= Grass HP
# H1 = Dragon HP > Grass HP

st.ttest_ind(df_filtered_dragon["HP"], df_filtered_grass["HP"], alternative = "greater")
# Out:
# TtestResult(statistic=4.4991348531252635, pvalue=7.009713739308821e-06, df=143.0)

# %% [markdown]
# Al ser el p-value menor a 0.05 rechazamos la hipótesis H0 y tenemos una certeza del 95% de que se cumple la H1

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
# Comprobar las columnas que vamos a usar del df
df_pokemon.head(5)
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2       Venusaur  Grass  Poison  80      82       83      100      100     80
# 3  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 4     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False

# %%
# Crear df filtrado con las columnas necesarias
df_filtered_stats = df_pokemon[["Name", "HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]]
df_filtered_stats
# Out:
#                Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0         Bulbasaur  45      49       49       65       65     45
# 1           Ivysaur  60      62       63       80       80     60
# 2          Venusaur  80      82       83      100      100     80
# 3     Mega Venusaur  80     100      123      122      120     80
# 4        Charmander  39      52       43       60       50     65
# ..              ...  ..     ...      ...      ...      ...    ...
# 795         Diancie  50     100      150      100      150     50
# 796    Mega Diancie  50     160      110      160      110    110
# 797  Hoopa Confined  80     110       60      150      130     70
# 798   Hoopa Unbound  80     160       60      170      130     80
# 799       Volcanion  80     110      120      130       90     70
#
# [800 rows x 7 columns]

# %%
df_stats_legendary = df_filtered_stats[(df_pokemon["Legendary"].isin([True]))]
df_stats_legendary
# Out:
#                Name   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 156        Articuno   90      85      100       95      125     85
# 157          Zapdos   90      90       85      125       90    100
# 158         Moltres   90     100       90      125       85     90
# 162          Mewtwo  106     110       90      154       90    130
# 163   Mega Mewtwo X  106     190      100      154      100    130
# ..              ...  ...     ...      ...      ...      ...    ...
# 795         Diancie   50     100      150      100      150     50
# 796    Mega Diancie   50     160      110      160      110    110
# 797  Hoopa Confined   80     110       60      150      130     70
# 798   Hoopa Unbound   80     160       60      170      130     80
# 799       Volcanion   80     110      120      130       90     70
#
# [65 rows x 7 columns]

# %%
df_stats_non_legendary = df_filtered_stats[(df_pokemon["Legendary"].isin([False]))]
df_stats_non_legendary
# Out:
#                      Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0               Bulbasaur  45      49       49       65       65     45
# 1                 Ivysaur  60      62       63       80       80     60
# 2                Venusaur  80      82       83      100      100     80
# 3           Mega Venusaur  80     100      123      122      120     80
# 4              Charmander  39      52       43       60       50     65
# ..                    ...  ..     ...      ...      ...      ...    ...
# 787  Gourgeist Super Size  85     100      122       58       75     54
# 788              Bergmite  55      69       85       32       35     28
# 789               Avalugg  95     117      184       44       46     28
# 790                Noibat  40      30       35       45       40     55
# 791               Noivern  85      70       80       97       80    123
#
# [735 rows x 7 columns]

# %%
# Usar ANOVA para comprobar todos los stats entre pokemon legendarios y no legendarios.
# Calcula con Paired Sample T-test que los stats de los Pokemon legendarios son iguales a los Pokemon no legendarios
# Y así confirmamos que al no ser iguales, podemos decir que son diferentes.
# H0: Legendary Pokemon Stats = Non Legendary Pokemon Stats
# H1: Legendary Pokemon Stats != Non Legendary Pokemon Stats

t_stats, p_value = st.ttest_ind(df_stats_non_legendary[["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]], df_stats_legendary[["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]], alternative = "two-sided")

# %%
p_value
# Out:
# array([3.33064768e-15, 7.82725300e-24, 1.58422261e-12, 6.31491577e-41,
#        1.84398096e-26, 2.35407544e-21])

# %%
H0 = "Fail to reject the null hypothesis: There's no evidence to check that Legendary Pokemon Stats != Non Legendary Stats."
H1 = "Reject the null hypothesis: Legendary Pokemon Stats != Non Legendary Stats."
alpha = 0.05

if (p_value < alpha).all(): print(H1)
else: print(H0)
# Out:
# Reject the null hypothesis: Legendary Pokemon Stats != Non Legendary Stats.

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df_housing = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df_housing

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 37)
# - Hospital coordinates (-122, 34)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
# Coordenadas de la escuela y el hospital
school_coords = (-118, 37)
hospital_coords = (-122, 34)

# Función para calcular la distancia euclidiana
def euclidean_distance(lat1, lon1, lat2, lon2):
    return np.sqrt((lat2 - lat1)**2 + (lon2 - lon1)**2)

# Calcular la distancia de cada casa a la escuela y al hospital
df_housing["distance_to_school"] = df_housing.apply(lambda row: euclidean_distance(
    row["latitude"], row["longitude"], school_coords[1], school_coords[0]), axis=1)

df_housing["distance_to_hospital"] = df_housing.apply(lambda row: euclidean_distance(
    row["latitude"], row["longitude"], hospital_coords[1], hospital_coords[0]), axis=1)

# %%
# Clasificar si las casas están cerca de una escuela o un hospital
df_housing["close_to_school_or_hospital"] = (df_housing["distance_to_school"] < 0.50) | (df_housing["distance_to_hospital"] < 0.50)

# %%
import scipy.stats as stats

# Dividir las casas en cercanas y lejanas
close_houses = df_housing[df_housing["close_to_school_or_hospital"] == True]["median_house_value"]
far_houses = df_housing[df_housing["close_to_school_or_hospital"] == False]["median_house_value"]

# Prueba ANOVA
f_stat, p_value = stats.f_oneway(close_houses, far_houses)
f_stat, p_value

# %%
H0 = "H0 (There is no significant difference in prices)."
H1 = "H1 (There is a significant difference in prices)."
alpha = 0.05
if p_value < alpha:
    print(f"Result: {H1} (p-value = {p_value:.4f}).")
else:
    print(f"Result: {H0} (p-value = {p_value:.4f}).")
